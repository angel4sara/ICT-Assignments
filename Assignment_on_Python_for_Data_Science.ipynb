# %% [markdown]
# <a href="https://colab.research.google.com/github/angel4sara/ICT-Assignments/blob/main/Assignment_on_Python_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np  #  Importing the numpy library
import pandas as pd  #  Importing the pandas library
import matplotlib.pyplot as plt  #  Importing the matplotlib library for visualisation
import seaborn as sns  #  Importing the seaborn library for visualisation

# %% [markdown]
# ## Reading the iris excel file

# %% [markdown]
# ### 1. Read the dataset to the python environment.

# %%
data_iris = pd.read_excel('/content/iris.xls')

# %% [markdown]
# If we convert the excel file to csv file we can use the function *pd.read_csv* , since excel file is used , we use the function *pd.read_excel* .

# %% [markdown]
# ## Displaying the dataset

# %% [markdown]
# ###  2. Display the columns in the dataset.

# %%
data_iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# * Displaying the column headings.

# %%
data_iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# * Displaying the frist 5 rows.

# %%
data_iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# * Displaying the frist 20 rows.

# %%
data_iris.head(20)
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa
# 11  4.8  3.4  1.6  0.2    Iris-setosa
# 12  4.8  3.0  1.4  0.1    Iris-setosa
# 13  4.3  3.0  1.1  0.1    Iris-setosa
# 14  5.8  4.0  1.2  0.2    Iris-setosa
# 15  5.7  4.4  1.5  0.4    Iris-setosa
# 16  5.4  3.9  1.3  0.4    Iris-setosa
# 17  5.1  3.5  1.4  0.3    Iris-setosa
# 18  5.7  3.8  1.7  0.3    Iris-setosa
# 19  5.1  3.8  1.5  0.3    Iris-setosa

# %% [markdown]
# * Displaying the last 5 rows.

# %%
data_iris.tail()
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# * Displaying the last 20 rows.

# %%
data_iris.tail(20)
# Out:
#       SL   SW   PL   PW  Classification
# 130  7.4  2.8  6.1  1.9  Iris-virginica
# 131  7.9  3.8  6.4  2.0  Iris-virginica
# 132  6.4  2.8  5.6  2.2  Iris-virginica
# 133  6.3  2.8  5.1  1.5  Iris-virginica
# 134  6.1  2.6  5.6  1.4  Iris-virginica
# 135  7.7  3.0  6.1  2.3  Iris-virginica
# 136  6.3  3.4  5.6  2.4  Iris-virginica
# 137  6.4  3.1  5.5  1.8  Iris-virginica
# 138  6.0  3.0  4.8  1.8  Iris-virginica
# 139  6.9  3.1  5.4  2.1  Iris-virginica
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# * Details about the data types, null values.

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Statistical Operations

# %% [markdown]
# ###  3. Calculate the mean of each column of the dataset.

# %%
data_iris[['SL', 'SW', 'PL', 'PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# *  Mean of SL is 5.843333
# *  Mean of SW is 3.054000
# *  Mean of PL is 3.758667
# *  Mean of PW is 1.198667

# %%
data_iris.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# * describe() gives statistical information about the data like mean, standard deviation, minimum value, maximum value, 25th quartile, 50th quartile, 75th quartile.
# * We cant find the mean of the column 'Classification' because it contains object.
# * Alternatively, we can do is --

# %%
data_iris.describe(include ='object')
# Out:
#        Classification
# count             150
# unique              3
# top       Iris-setosa
# freq               50

# %% [markdown]
# * We can describe the total counts, unique values, frequent value and its frequency of the column containing objects.

# %% [markdown]
# ## Null Values

# %% [markdown]
# ###  4. Check for the null values present in the dataset.

# %%
data_iris.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data_iris.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# * Here, it can be seen that there is no null values present.
# * info() also helps to identify if there is any null values present.

# %%
data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# * it says there 150 non-null implying out of 150, 150 is non-null.
# * Thus there is no null values present

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ###  5. Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations

# %% [markdown]
# ### **Heatmap**

# %%
corr = data_iris.iloc[:, :-1].corr()
sns.heatmap(corr, annot =True, cmap ='RdBu')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# From the Heatmap above:
# * Petal Length and Petal Width has the highest positive correlation followed by Petal Length and Sepal Length.
# *Petal Length and Sepal Width has highest negative correlation followed by Petal Width and Sepal Width.

# %% [markdown]
# ### **Pair Plot**

# %%
Plots = sns.pairplot(data_iris, hue='Classification')
Plots.fig.suptitle('Pairplot of the Iris Data', y=1.02)
plt.show()

# %% [markdown]
# The pairplot depicts:
# * The Iris-setosa has a clear distinction or separation from other groups in terms of Sepal Length, Sepal Width, Petal Length and Petal Width.
# * The petal length and petal width is the most distinguishable among the group of setosa, versicolor and virginica.

# %% [markdown]
# ### **Box Plot**

# %%
sns.boxplot(data_iris, x = 'Classification', y = 'PL', hue ='Classification', palette = ['purple','green','yellow'])
plt.title('Petal Length Distributiion by Classification')
plt.show(block=True)

# %% [markdown]
# Fom the boxplot:
# * Virginica has the highest and wide range of petal length.
# * Setosa has the smallest petal length with a few outliers.
# * Virginica and Versicolor has an overlapping range in terms of petal length thus difficult to distinguish in tyerms of petal length.

# %% [markdown]
# ### **Bar Plot**

# %%
sns.barplot(data=data_iris, x='Classification', y='SL', hue ='Classification',palette = ['purple','green','yellow'])
plt.title('Average Sepal Length by Species')
plt.show()

# %% [markdown]
# The Bar Plot depicts:
# * Virginica has the largest sepal length followed by Versicolor.
# * Setosa has smallest Sepal Length.
